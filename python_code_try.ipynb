# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
array = ["a", "b", "c"]
array1 = [1, 2, 3]
array2 = [11, 12, 13]
array3 = [11, pd.NA, 13]
df = pd.DataFrame(array1, columns=["1st"])
df["2nd"] = array2
df2 = pd.DataFrame(array1, columns=["1st"])
df2["3rd"] = array3
dic = {"A": 101, "B": 102, "C": 103}

# %%
y = 7
if y > 10:
    print("10より大きい")
elif y > 5:
    print("5より大きい")
else:
    print("それ以外")
# Out:
# 5より大きい

# %%
x = 8
'even' if x % 2 == 0 else 'odd'
# Out:
# 'even'

# %%
x = -3
'negative' if x < 0 else 'positive' if x > 0 else 'zero'
# Out:
# 'negative'

# %%
arr = []
for i in [10, 100, 1000]:
    arr.append(i) if i >=100 else None
arr
# Out:
# [100, 1000]

# %%
num = 10
print(num > 5 and num < 20)
print(num > 5 and num < 8)
# Out:
# True
# False

# %%
num = 10
print(num > 5 or num < 20)
print(num > 5 or num < 8)
# Out:
# True
# True

# %%
num = 10
print(not num > 5)
print(not num < 8)
# Out:
# False
# True

# %%
print (1 in [0, 1, 2])
print(100 in [0, 1, 2])
# Out:
# True
# False

# %%
print(1 in (0, 1, 2))
print(1 in {0, 1, 2})
print(1 in range(3))
# Out:
# True
# True
# True

# %%
print('A' in dic)
print(101 in dic)
print(101 in dic.values())
print(('A', 101) in dic.items())
print(('A', 102) in dic.items())
# Out:
# True
# False
# True
# True
# False

# %%
print('a' in 'abc')
print([1, 2] in [1, 2, 3])
print(set([1, 2]) <= set([1, 2, 3]))
set([1, 2, 3])
# Out:
# True
# False
# True
# {1, 2, 3}

# %%
print(not 1 in [1, 2, 3])
print(not 10 in [1, 2, 3])
# Out:
# False
# True

# %%
print([1, 2, 3] == [1, 2, 3])
print([1, 2, 3] is [1, 2, 3])
# Out:
# True
# False

# %%
from math import pi

pi
# Out:
# 3.141592653589793

# %%
from math import radians as rad

rad(180)
# Out:
# 3.141592653589793

# %%
class message(): # クラス名=message
    def hello(self): # メソッド名=hello
        print("Hello!") # 実行したい処理=「Hello!」を出力
mess = message() # インスタンス名=mess
mess.hello() # 呼び出し
# Out:
# Hello!

# %%
try:
    print(1 / 0)
except ZeroDivisionError as e:
    print('Error')
    print(e)
finally:print('finish')
# Out:
# Error
# division by zero
# finish

# %%
df = pd.DataFrame(array1, columns=["1st"])
df["2nd"] = array2

new_array = [*array]
new_array = [*new_array, "d"]
print(array)
print(new_array)
print([*dic])
print([*df])
print([*df.columns])
print([*df.values.tolist()])
# Out:
# ['a', 'b', 'c']
# ['a', 'b', 'c', 'd']
# ['A', 'B', 'C']
# ['1st', '2nd']
# ['1st', '2nd']
# [[1, 11], [2, 12], [3, 13]]

# %%
abs(-5)
# Out:
# 5

# %%
all([True, False, True])
# Out:
# False

# %%
any([True, False, True])
# Out:
# True

# %%
ascii('あ')
# Out:
# "'\\u3042'"

# %%
bin(10)
# Out:
# '0b1010'

# %%
print(bool(0 == 0))
print(bool(0 == 1))
# Out:
# True
# False

# %%
print(bytearray([255]))
# Out:
# bytearray(b'\xff')

# %%
bytes([65, 66, 67])
# Out:
# b'ABC'

# %%
callable(print)
# Out:
# True

# %%
chr(8364)
# Out:
# '€'

# %%
code = """
def greet(name):
    print("Hello, " + name + "!")

greet("Alice")
"""

compiled_code = compile(code, "<string>", "exec")
exec(compiled_code)
# Out:
# Hello, Alice!

# %%
complex(1, 2)
# Out:
# (1+2j)

# %%
def add(a, b=1):
    result = a + b
    return result
print(add(3, 4))
print(add(3))
# Out:
# 7
# 4

# %%
array_copy = array.copy()
del array_copy[1]
array_copy
# Out:
# ['a', 'c']

# %%
dic_copy = dic.copy()
dic_copy
# Out:
# {'A': 101, 'B': 102, 'C': 103}

# %%
df_copy = df.copy()
df_copy
# Out:
#    1st  2nd
# 0    1   11
# 1    2   12
# 2    3   13

# %%
dict(name='John', age=30)
# Out:
# {'name': 'John', 'age': 30}

# %%
import math
dir(math)
# Out:
# ['__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'acos',
#  'acosh',
#  'asin',
#  'asinh',
#  'atan',
#  'atan2',
#  'atanh',
#  'cbrt',
#  'ceil',
#  'comb',
#  'copysign',
#  'cos',
#  'cosh',
#  'degrees',
#  'dist',
#  'e',
#  'erf',
#  'erfc',
#  'exp',
#  'exp2',
#  'expm1',
#  'fabs',
#  'factorial',
#  'floor',
#  'fmod',
#  'frexp',
#  'fsum',
#  'gamma',
#  'gcd',
#  'hypot',
#  'inf',
#  'isclose',
#  'isfinite',
#  'isinf',
#  'isnan',
#  'isqrt',
#  'lcm',
#  'ldexp',
#  'lgamma',
#  'log',
#  'log10',
#  'log1p',
#  'log2',
#  'modf',
#  'nan',
#  'nextafter',
#  'perm',
#  'pi',
#  'pow',
#  'prod',
#  'radians',
#  'remainder',
#  'sin',
#  'sinh',
#  'sqrt',
#  'tan',
#  'tanh',
#  'tau',
#  'trunc',
#  'ulp']

# %%
print(divmod(10, 3)) 
print(divmod(10, 3)[0]) 
print(divmod(10, 3)[1])
# Out:
# (3, 1)
# 3
# 1

# %%
for index, value in enumerate(array, start=3):
    print(index, value)
# Out:
# 3 a
# 4 b
# 5 c

# %%
list(enumerate(['a', 'b', 'c']))
# Out:
# [(0, 'a'), (1, 'b'), (2, 'c')]

# %%
eval('2 + 3')
# Out:
# 5

# %%
exec(f"print('Hello')")
# Out:
# Hello

# %%
list(filter(lambda x: x % 2 == 0, [1, 2, 3, 4]))
# Out:
# [2, 4]

# %%
print(float(3))
print(float('3.14'))
# Out:
# 3.0
# 3.14

# %%
print(format(0.5, '.2f'))
print(format(123456789, ',d'))
# Out:
# 0.50
# 123,456,789

# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for i in array:
    print(i)
# Out:
# a
# b
# c

# %%
for i in dic:
    print(i, dic[i])
# Out:
# A 101
# B 102
# C 103

# %%
for column_name, item in df.items():
    print(column_name)
    print(item)
# Out:
# 1st
# 0    1
# 1    2
# 2    3
# Name: 1st, dtype: int64
# 2nd
# 0    11
# 1    12
# 2    13
# Name: 2nd, dtype: int64

# %%
for index, row in df.iterrows():
    print(index)
    print(row.values)
row.values
# Out:
# 0
# [ 1 11]
# 1
# [ 2 12]
# 2
# [ 3 13]
# array([ 3, 13], dtype=int64)

# %%
for row in df.itertuples():
    print(row[1])
# Out:
# 1
# 2
# 3

# %%
for row in df.itertuples(index=False, name=None):
    print(row)
# Out:
# (1, 11)
# (2, 12)
# (3, 13)

# %%
for i in df["1st"]:
    print(i)
# Out:
# 1
# 2
# 3

# %%
for i, j in zip(df['1st'], df['2nd']):
    print(i, j)
# Out:
# 1 11
# 2 12
# 3 13

# %%
for i, j in zip(df.iloc[:, 0], df.iloc[:, 1]):
    print(i, j)
# Out:
# 1 11
# 2 12
# 3 13

# %%
for i in array:
    print(i)
else:
    print('END')
# Out:
# a
# b
# c
# END

# %%
for num in [1, 2, 3.5, 4, 5]:
    if not isinstance(num, int):
        print(f'スキップしました（{num}は整数ではないため）。')
        continue
    print(num)
# Out:
# 1
# 2
# スキップしました（3.5は整数ではないため）。
# 4
# 5

# %%
for i in [1, 2, 3]:
    for j in [11, 2, 13]:
        print(i, j)
        if i == j:
            print('BREAK')
            break
# Out:
# 1 11
# 1 2
# 1 13
# 2 11
# 2 2
# BREAK
# 3 11
# 3 2
# 3 13

# %%
count = 0
while count < 5:
    print(count)
    count += 1
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
frozenset([1, 2, 3])
# Out:
# frozenset({1, 2, 3})

# %%
globals()
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
#   'import pandas as pd\nimport numpy as np\nimport matplotlib.pyplot as plt\nimport seaborn as sns',
#   'array = ["a", "b", "c"]\narray1 = [1, 2, 3]\narray2 = [11, 12, 13]\narray3 = [11, pd.NA, 13]\ndf = pd.DataFrame(array1, columns=["1st"])\ndf["2nd"] = array2\ndf2 = pd.DataFrame(array1, columns=["1st"])\ndf2["3rd"] = array3\ndic = {"A": 101, "B": 102, "C": 103}',
#   'y = 7\nif y > 10:\n    print("10より大きい")\nelif y > 5:\n    print("5より大きい")\nelse:\n    print("それ以外")',
#   "x = 8\n'even' if x % 2 == 0 else 'odd'",
#   "x = -3\n'negative' if x < 0 else 'positive' if x > 0 else 'zero'",
#   'arr = []\nfor i in [10, 100, 1000]:\n    arr.append(i) if i >=100 else None\narr',
# ...

# %%
print(hash('hello'))
# Out:
# 769562730701076202

# %%
help(str)
# Out:
# Help on class str in module builtins:
#
# class str(object)
#  |  str(object='') -> str
#  |  str(bytes_or_buffer[, encoding[, errors]]) -> str
#  |
#  |  Create a new string object from the given object. If encoding or
#  |  errors is specified, then the object must expose a data buffer
#  |  that will be decoded using the given encoding and error handler.
#  |  Otherwise, returns the result of object.__str__() (if defined)
#  |  or repr(object).
#  |  encoding defaults to sys.getdefaultencoding().
#  |  errors defaults to 'strict'.
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return key in self.
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __format__(self, format_spec, /)
#  |      Return a formatted version of the string as described by format_spec.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
# ...

# %%
hex(255)
# Out:
# '0xff'

# %%
id(array)
# Out:
# 1672673923008

# %%
input('Enter your name: ')
# Out:
# ''

# %%
print(int(3.14))
print(int('3'))
print(int(float('3.14')))
# Out:
# 3
# 3
# 3

# %%
list(iter(dic))
# Out:
# ['A', 'B', 'C']

# %%
add = lambda a, b=1: a + b
print(add(3, 4))
print(add(3))
# Out:
# 7
# 4

# %%
len([1, 2, 3])
# Out:
# 3

# %%
df = pd.DataFrame(array1, columns=["1st"])
df["2nd"] = array2

print(list([1 ,2, 3]))
print(list(array))
print(list(dic))
print(list(df))
print(list(df.columns))
print(list(df.values.tolist()))
# Out:
# [1, 2, 3]
# ['a', 'b', 'c']
# ['A', 'B', 'C']
# ['1st', '2nd']
# ['1st', '2nd']
# [[1, 11], [2, 12], [3, 13]]

# %%
locals()
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
#   'import pandas as pd\nimport numpy as np\nimport matplotlib.pyplot as plt\nimport seaborn as sns',
#   'array = ["a", "b", "c"]\narray1 = [1, 2, 3]\narray2 = [11, 12, 13]\narray3 = [11, pd.NA, 13]\ndf = pd.DataFrame(array1, columns=["1st"])\ndf["2nd"] = array2\ndf2 = pd.DataFrame(array1, columns=["1st"])\ndf2["3rd"] = array3\ndic = {"A": 101, "B": 102, "C": 103}',
#   'y = 7\nif y > 10:\n    print("10より大きい")\nelif y > 5:\n    print("5より大きい")\nelse:\n    print("それ以外")',
#   "x = 8\n'even' if x % 2 == 0 else 'odd'",
#   "x = -3\n'negative' if x < 0 else 'positive' if x > 0 else 'zero'",
#   'arr = []\nfor i in [10, 100, 1000]:\n    arr.append(i) if i >=100 else None\narr',
# ...

# %%
list(map(lambda x: x*2, [1, 2, 3]))
# Out:
# [2, 4, 6]

# %%
array1 = [1, 2, 3]
list(map(lambda x: x*2, array1))
# Out:
# [2, 4, 6]

# %%
df.map(lambda x: x * 2)
# Out:
#    1st  2nd
# 0    2   22
# 1    4   24
# 2    6   26

# %%
max(4, 7, 2)
# Out:
# 7

# %%
memoryview(b'hello')

# %%
min(4, 7, 2)
# Out:
# 2

# %%
iter = iter([1, 2, 3])
print(next(iter))
print(next(iter))
# Out:
# 1
# 2

# %%
object()

# %%
oct(8)
# Out:
# '0o10'

# %%
# with open('file.txt', 'r', encoding='utf-8') as file:
#     file_content = file.read()

# %%
ord("A")
# Out:
# 65

# %%
pow(2, 3)
# Out:
# 8

# %%
print('Hello, World!')
print(f'array: {array}')
# Out:
# Hello, World!
# array: ['a', 'b', 'c']

# %%
print(list(range(5)))
print(list(range(3, 10, 2)))
# Out:
# [0, 1, 2, 3, 4]
# [3, 5, 7, 9]

# %%
repr(dic)
# Out:
# "{'A': 101, 'B': 102, 'C': 103}"

# %%
print(list(reversed([1, 2, 3])))
print(list(reversed('apple')))
# Out:
# [3, 2, 1]
# ['e', 'l', 'p', 'p', 'a']

# %%
round(3.14159, 2)
# Out:
# 3.14

# %%
print(set([1, 2, 3]))
print(set(dic))
# Out:
# {1, 2, 3}
# {'B', 'C', 'A'}

# %%
print(array[1:])
print(array[:1])
print(array[:-1])
print(array[::2])
print(array[::-1])
print(df.iloc[2:, 1:])
# Out:
# ['b', 'c']
# ['a']
# ['a', 'b']
# ['a', 'c']
# ['c', 'b', 'a']
#    2nd
# 2   13

# %%
sorted([3, 1, 4, 1, 5, 9, 2])
# Out:
# [1, 1, 2, 3, 4, 5, 9]

# %%
str(42)
# Out:
# '42'

# %%
sum([1, 2, 3])
# Out:
# 6

# %%
print(tuple([1, 2, 3]))
print(tuple(dic))
# Out:
# (1, 2, 3)
# ('A', 'B', 'C')

# %%
type(dic)
# Out:
# dict

# %%
vars()
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
#   'import pandas as pd\nimport numpy as np\nimport matplotlib.pyplot as plt\nimport seaborn as sns',
#   'array = ["a", "b", "c"]\narray1 = [1, 2, 3]\narray2 = [11, 12, 13]\narray3 = [11, pd.NA, 13]\ndf = pd.DataFrame(array1, columns=["1st"])\ndf["2nd"] = array2\ndf2 = pd.DataFrame(array1, columns=["1st"])\ndf2["3rd"] = array3\ndic = {"A": 101, "B": 102, "C": 103}',
#   'y = 7\nif y > 10:\n    print("10より大きい")\nelif y > 5:\n    print("5より大きい")\nelse:\n    print("それ以外")',
#   "x = 8\n'even' if x % 2 == 0 else 'odd'",
#   "x = -3\n'negative' if x < 0 else 'positive' if x > 0 else 'zero'",
#   'arr = []\nfor i in [10, 100, 1000]:\n    arr.append(i) if i >=100 else None\narr',
# ...

# %%
print(list(zip([1, 2, 3], ['a', 'b', 'c'])))
print(list(zip(array, [1, 2, 3], ['a', 'b', 'c'])))
print(list(zip(array, "ABCDE")))
# Out:
# [(1, 'a'), (2, 'b'), (3, 'c')]
# [('a', 1, 'a'), ('b', 2, 'b'), ('c', 3, 'c')]
# [('a', 'A'), ('b', 'B'), ('c', 'C')]

# %%
dict.fromkeys([3, 3, 2, 1, 5, 1, 4, 2, 3])
# Out:
# {3: None, 2: None, 1: None, 5: None, 4: None}

# %%
array = ["a", "b", "c"]
array.append("D")
array
# Out:
# ['a', 'b', 'c', 'D']

# %%
array = ["a", "b", "c"]
array.insert(1, "D")
array
# Out:
# ['a', 'D', 'b', 'c']

# %%
array = ["a", "b", "c"]
array.extend(["D", "E"])
array
# Out:
# ['a', 'b', 'c', 'D', 'E']

# %%
array = ["a", "b", "c"]
array += (["D", "E"])
array
# Out:
# ['a', 'b', 'c', 'D', 'E']

# %%
array = ["a", "b", "c"]
array.remove("b")
array
# Out:
# ['a', 'c']

# %%
array = ["a", "b", "c"]
del array[1]
array
# Out:
# ['a', 'c']

# %%
array = ["a", "b", "c"]
x = array.pop(1)
print(array, x)
# Out:
# ['a', 'c'] b

# %%
array = ["a", "b", "c"]
array.clear()
array
# Out:
# []

# %%
array = ["a", "b", "c"]
array.index('b')
# Out:
# 1

# %%
array = [1, 2, 2, 3]
array.count(2)
# Out:
# 2

# %%
array = [3, 1, 4]
array.sort()
array
# Out:
# [1, 3, 4]

# %%
array = [1, 2, 3]
array.reverse()
array
# Out:
# [3, 2, 1]

# %%
array = ['a', 'b', 'c']
my = '-'
my.join(array)
# Out:
# 'a-b-c'

# %%
data =[[1, 2, 3], [4, 5, 6]]
df_data = pd.DataFrame(data, columns=["A", "B", "C"])
df_data
# Out:
#    A  B  C
# 0  1  2  3
# 1  4  5  6

# %%
df = pd.DataFrame(array1, columns=["1st"])
df["2nd"] = array2
df.head(2)
# Out:
#    1st  2nd
# 0    1   11
# 1    2   12

# %%
df.tail(2)
# Out:
#    1st  2nd
# 1    2   12
# 2    3   13

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   1st     3 non-null      int64
#  1   2nd     3 non-null      int64
# dtypes: int64(2)
# memory usage: 180.0 bytes

# %%
df.describe()
# Out:
#        1st   2nd
# count  3.0   3.0
# mean   2.0  12.0
# std    1.0   1.0
# min    1.0  11.0
# 25%    1.5  11.5
# 50%    2.0  12.0
# 75%    2.5  12.5
# max    3.0  13.0

# %%
df.shape
# Out:
# (3, 2)

# %%
df.values
# Out:
# array([[ 1, 11],
#        [ 2, 12],
#        [ 3, 13]], dtype=int64)

# %%
list(df.index)
# Out:
# [0, 1, 2]

# %%
list(df.columns)
# Out:
# ['1st', '2nd']

# %%
df['2nd']
# Out:
# 0    11
# 1    12
# 2    13
# Name: 2nd, dtype: int64

# %%
df['2nd'].unique
# Out:
# <bound method Series.unique of 0    11
# 1    12
# 2    13
# Name: 2nd, dtype: int64>

# %%
df2
# Out:
#    1st   3rd
# 0    1    11
# 1    2  <NA>
# 2    3    13

# %%
df2.isnull()
# Out:
#      1st    3rd
# 0  False  False
# 1  False   True
# 2  False  False

# %%
df2_copy = df2.copy()
df2_copy.dropna()
# Out:
#    1st 3rd
# 0    1  11
# 2    3  13

# %%
df.fillna(df.mean(numeric_only=True))
# Out:
#    1st  2nd
# 0    1   11
# 1    2   12
# 2    3   13

# %%
data = {'A': [1, 2, 3, 4, 5],
        'B': ['apple', 'banana', 'orange', 'apple', 'grape'],
        'C': [0.5, 0.7, 0.2, 0.9, 0.4]}

df3 = pd.DataFrame(data)

# 'A' 列が指定した値のいずれかに含まれる行を抽出
result = df3[df3['A'].isin([2, 4, 6])]

print(result)
# Out:
#    A       B    C
# 1  2  banana  0.7
# 3  4   apple  0.9

# %%
df3[df3['A']>3]
# Out:
#    A      B    C
# 3  4  apple  0.9
# 4  5  grape  0.4

# %%
grouped_data = df3.groupby('B').mean()
grouped_data
# Out:
#           A    C
# B
# apple   2.5  0.7
# banana  2.0  0.7
# grape   5.0  0.4
# orange  3.0  0.2

# %%
df_num = pd.DataFrame(df3.groupby('B').size(), columns=['num'])
df_num
# Out:
#         num
# B
# apple     2
# banana    1
# grape     1
# orange    1

# %%
df3.plot()
# Out:
# <Axes: >

# %%
df3.plot(x='A', y='C', kind='scatter')
# Out:
# <Axes: xlabel='A', ylabel='C'>

# %%
def double(x):
    return x * 2

print(df.apply(double))
print(df["2nd"].apply(lambda x: x * 2))
# Out:
#    1st  2nd
# 0    2   22
# 1    4   24
# 2    6   26
# 0    22
# 1    24
# 2    26
# Name: 2nd, dtype: int64

# %%
def double(x):
    return x * 2

print(df.map(double))
print(df["2nd"].map(lambda x: x * 2))
# Out:
#    1st  2nd
# 0    2   22
# 1    4   24
# 2    6   26
# 0    22
# 1    24
# 2    26
# Name: 2nd, dtype: int64

# %%
def double(x):
    return x * 2

result = df.applymap(double)
result
# Out:
# C:\Users\1465151\AppData\Local\Temp\ipykernel_15924\1656140643.py:4: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   result = df.applymap(double)
#    1st  2nd
# 0    2   22
# 1    4   24
# 2    6   26

# %%
print(df.filter(items=['1st']))
print(df.filter(like='2', axis=0))
print(df.filter(like='n', axis=1))
# Out:
#    1st
# 0    1
# 1    2
# 2    3
#    1st  2nd
# 2    3   13
#    2nd
# 0   11
# 1   12
# 2   13

# %%
df.query("`2nd` > 11")
# Out:
#    1st  2nd
# 1    2   12
# 2    3   13

# %%
df[df['2nd'] > 11]
# Out:
#    1st  2nd
# 1    2   12
# 2    3   13

# %%
df.query("`1st`*10 < `2nd`")
# Out:
#    1st  2nd
# 0    1   11

# %%
df.loc[1, "2nd"]
# Out:
# 12

# %%
df.loc[1, :]
# Out:
# 1st     2
# 2nd    12
# Name: 1, dtype: int64

# %%
df.iloc[1, 1]
# Out:
# 12

# %%
df.iloc[1:, 1]
# Out:
# 1    12
# 2    13
# Name: 2nd, dtype: int64

# %%
df.at[1, "2nd"]
# Out:
# 12

# %%
df.iat[1, 1]
# Out:
# 12

# %%
df.to_dict()
# Out:
# {'1st': {0: 1, 1: 2, 2: 3}, '2nd': {0: 11, 1: 12, 2: 13}}

# %%
df.to_dict(orient='list')
# Out:
# {'1st': [1, 2, 3], '2nd': [11, 12, 13]}

# %%
arr = np.array([[1, 2, 3], [4, 5, 6]])
arr[0,1]
# Out:
# 2

# %%
arr = np.array([[1, 2, 3], [4, 5, 6]])
list = arr.tolist()
list
# Out:
# [[1, 2, 3], [4, 5, 6]]

# %%
zeros_arr = np.zeros((2, 3))
zeros_arr
# Out:
# array([[0., 0., 0.],
#        [0., 0., 0.]])

# %%
ones_arr = np.ones((2, 3))
ones_arr
# Out:
# array([[1., 1., 1.],
#        [1., 1., 1.]])

# %%
arange_arr = np.arange(0, 10, 2)
arange_arr
# Out:
# array([0, 2, 4, 6, 8])

# %%
linspace_arr = np.linspace(0, 1, 5)
linspace_arr
# Out:
# array([0.  , 0.25, 0.5 , 0.75, 1.  ])

# %%
rand_arr = np.random.rand(2, 3)
rand_arr
# Out:
# array([[0.42505652, 0.04547706, 0.08475765],
#        [0.69282487, 0.969916  , 0.10226969]])

# %%
randn_arr = np.random.randn(2, 3)
randn_arr
# Out:
# array([[-0.37691635,  1.54296197,  0.69396108],
#        [ 0.71146376,  1.4776963 , -1.16713997]])

# %%
arr = np.array([[1, 2, 3], [4, 5, 6]])
shape = np.shape(arr)
shape
# Out:
# (2, 3)

# %%
arr = np.array([[1, 2, 3], [4, 5, 6]])
reshaped_arr = np.reshape(arr, (3, 2))
reshaped_arr
# Out:
# array([[1, 2],
#        [3, 4],
#        [5, 6]])

# %%
arr = np.array([[1, 2, 3], [4, 5, 6]])
transposed_arr = np.transpose(arr)
transposed_arr
# Out:
# array([[1, 4],
#        [2, 5],
#        [3, 6]])

# %%
arr1 = np.array([1, 2, 3])
arr2 = np.array([1, 2, 3])
dot_product = np.dot(arr1, arr2)
dot_product
# Out:
# 14

# %%
arr = np.array([[1, 2, 3], [4, 5, 6]])
total = np.sum(arr)
total
# Out:
# 21

# %%
arr = np.array([[1, 2, 3], [4, 5, 6]])
average = np.mean(arr)
average
# Out:
# 3.5

# %%
arr = np.array([[1, 2, 3], [4, 5, 6]])
max = np.max(arr)
max
# Out:
# 6

# %%
arr = np.array([[1, 2, 3], [4, 5, 6]])
min = np.min(arr)
min
# Out:
# 1

# %%
arr = np.array([[1, 2, 3], [4, 5, 6]])
np.save('array.npy', arr)

# %%
loaded_arr = np.load('array.npy')
loaded_arr
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
x = [1, 2, 3, 4, 5]
y = [1, 2, 6, 7, 10]

plt.plot(x, y, label='Line')

# %%
plt.scatter(x, y, label='Points', color='red')

# %%
plt.bar(x, y, label='Bars', color='blue')
# Out:
# <BarContainer object of 5 artists>

# %%
data = np.random.randn(1000)
plt.hist(data, bins=20, color='green', alpha=0.7)
# Out:
# (array([  1.,   2.,   3.,   1.,   7.,  25.,  34.,  50.,  82., 100., 130.,
#         144., 134., 112.,  69.,  51.,  33.,  12.,   9.,   1.]),
#  array([-3.94254915, -3.59205461, -3.24156006, -2.89106552, -2.54057098,
#         -2.19007643, -1.83958189, -1.48908735, -1.13859281, -0.78809826,
#         -0.43760372, -0.08710918,  0.26338537,  0.61387991,  0.96437445,
#          1.314869  ,  1.66536354,  2.01585808,  2.36635263,  2.71684717,
#          3.06734171]),
#  <BarContainer object of 20 artists>)

# %%
plt.plot(x, y, label='Line')
plt.xlabel('X-axis Label')
# Out:
# Text(0.5, 0, 'X-axis Label')

# %%
plt.plot(x, y, label='Line')
plt.ylabel('Y-axis Label')
# Out:
# Text(0, 0.5, 'Y-axis Label')

# %%
plt.plot(x, y, label='Line')
plt.title('Graph Title')
# Out:
# Text(0.5, 1.0, 'Graph Title')

# %%
plt.plot(x, y, label='Line')
plt.legend()

# %%
plt.plot(x, y, label='Line')
plt.grid()

# %%
plt.plot(x, y, label='Line')
plt.grid()
plt.show()

# %%
plt.plot(x, y, label='Line')
plt.grid()
plt.savefig('graph.png')
plt.show()

# %%
# サブプロット1
plt.subplot(2, 1, 1)  # 2行1列の1番目のサブプロット
plt.plot(x, y, color='blue')
plt.title('Subplot1')

# サブプロット2
y2 = [10, 8, 4, 3, 1]
plt.subplot(2, 1, 2)  # 2行1列の2番目のサブプロット
plt.plot(x, y2, color='green')
plt.title('Subplot 2')

# サブプロットのレイアウト調整
plt.tight_layout()

# グラフを表示
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.plot(x, y, label='Line')

# %%
# データの作成
x3 = np.linspace(0, 10, 100)
y3 = np.sin(x)
colors = np.linspace(0, 1, len(x3))  # カラーマップに対応する色データ

# カラーマップを用いた散布図
scatter_plot = plt.scatter(x3, y3, c=colors, cmap='viridis', label='Line')

# カラーバーの表示
plt.colorbar(scatter_plot, label='Color')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[181], line 7
#       4 colors = np.linspace(0, 1, len(x3))  # カラーマップに対応する色データ
#       6 # カラーマップを用いた散布図
# ----> 7 scatter_plot = plt.scatter(x3, y3, c=colors, cmap='viridis', label='Line')
#       9 # カラーバーの表示
#      10 plt.colorbar(scatter_plot, label='Color')
#
# File c:\Users\1465151\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\pyplot.py:2862, in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, data, **kwargs)
#    2857 @_copy_docstring_and_deprecators(Axes.scatter)
#    2858 def scatter(
#    2859         x, y, s=None, c=None, marker=None, cmap=None, norm=None,
#    2860         vmin=None, vmax=None, alpha=None, linewidths=None, *,
#    2861         edgecolors=None, plotnonfinite=False, data=None, **kwargs):
# -> 2862     __ret = gca().scatter(
# ...

# %%
labels = ['Category A', 'Category B', 'Category C', 'Category D']
sizes = [25, 30, 20, 25] 
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90)
# Out:
# ([<matplotlib.patches.Wedge at 0x1e7ca6649d0>,
# ...
#  [Text(-0.7778174593052023, 0.7778174593052024, 'Category A'),
#   Text(-0.6465637441936395, -0.8899187180267095, 'Category B'),
#   Text(0.8899187482945414, -0.6465637025335375, 'Category C'),
#   Text(0.7778173864806729, 0.7778175321297249, 'Category D')],
#  [Text(-0.42426406871192845, 0.4242640687119285, '25.0%'),
#   Text(-0.3526711331965306, -0.48541020983275057, '30.0%'),
#   Text(0.4854102263424771, -0.3526711104728386, '20.0%'),
#   Text(0.42426402898945786, 0.4242641084343954, '25.0%')])

# %%
plt.plot(x, y, label='Line')
plt.axhline(y=4, color='black', linestyle='--')

# %%
plt.plot(x, y, label='Line')
plt.axvline(x=4, color='black', linestyle='--')

# %%
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(8, 6))

# %%
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(8, 6))
plt.tight_layout()

# %%
plt.scatter(x, y, alpha=0.5)

# %%
plt.plot(x, y, label='Line', linewidth=10)

# %%
plt.scatter(x, y, edgecolor='red')

# %%
plt.scatter(x, y, facecolor='red')

# %%
plt.plot(x, y, marker='o', markevery=2)

# %%
plt.plot(x, y, marker='o', markevery=2)
plt.style.use('default')

# %%
plt.plot(x, y, marker='o', markevery=2)
plt.style.use('ggplot')

# %%
plt.plot(x, y, marker='o', markevery=2)
plt.style.use('fivethirtyeight')

# %%
plt.plot(x, y, marker='o', markevery=2)
plt.style.use('bmh')

# %%
plt.plot(x, y, marker='o', markevery=2)
plt.style.use('dark_background')

# %%
plt.plot(x, y, marker='o', markevery=2)
plt.style.use('grayscale')

# %%
plt.plot(x, y, marker='o', markevery=2)
plt.style.use('seaborn-darkgrid')
# Out:
# C:\Users\1465151\AppData\Local\Temp\ipykernel_15808\2802258399.py:2: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-darkgrid')

# %%
plt.plot(x, y, marker='o', markevery=2)
plt.style.use('seaborn-poster')
# Out:
# C:\Users\1465151\AppData\Local\Temp\ipykernel_15808\3970089162.py:2: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-poster')

# %%
plt.plot(x, y, marker='o', markevery=2)
plt.style.use('seaborn-ticks')
# Out:
# C:\Users\1465151\AppData\Local\Temp\ipykernel_15808\3781629902.py:2: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-ticks')

# %%
plt.plot(x, y, marker='o', markevery=2)
plt.style.use('tableau-colorblind10')

# %%
df_sns = pd.DataFrame({'x_column': [1, 2, 3, 4, 5], 'y_column': [2, 3, 5, 9, 10]})
df_sns
# Out:
#    x_column  y_column
# 0         1         2
# 1         2         3
# 2         3         5
# 3         4         9
# 4         5        10

# %%
sns.set(style='whitegrid')
sns.scatterplot(x='x_column', y='y_column', data=df_sns)
# Out:
# c:\Users\1465151\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\1465151\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# <Axes: xlabel='x_column', ylabel='y_column'>

# %%
sns.lineplot(x='x_column', y='y_column', data=df_sns)
# Out:
# c:\Users\1465151\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\1465151\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\1465151\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
sns.barplot(x='x_column', y='y_column', data=df_sns)
# Out:
# c:\Users\1465151\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\1465151\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\1465151\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# <Axes: xlabel='x_column', ylabel='y_column'>

# %%
data = pd.DataFrame({'column': np.random.randn(100)})
sns.histplot(data=data, x='column', kde=True)
# Out:
# c:\Users\1465151\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\1465151\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='column', ylabel='Count'>

# %%
sns.boxplot(x='x_column', y='y_column', data=df_sns)
# Out:
# c:\Users\1465151\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\1465151\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\1465151\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# <Axes: xlabel='x_column', ylabel='y_column'>

# %%
sns.violinplot(x='x_column', y='y_column', data=df_sns)
# Out:
# c:\Users\1465151\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\1465151\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\1465151\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# <Axes: xlabel='x_column', ylabel='y_column'>

# %%
data = np.random.rand(5, 5)
correlation_matrix = np.corrcoef(data, rowvar=False)
sns.heatmap(data=correlation_matrix, annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %%
data = pd.DataFrame({
    'feature1': np.random.randn(100),
    'feature2': np.random.randn(100),
    'feature3': np.random.randn(100),
    'category_column': np.random.choice(['A', 'B', 'C'], 100)
})
sns.pairplot(data=data, hue='category_column')
# Out:
# c:\Users\1465151\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\1465151\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\1465151\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
sns.lmplot(x='x_column', y='y_column', data=df_sns)

# %%
data = pd.DataFrame({
    'x_column': np.random.choice(['A', 'B', 'C'], 100),
    'y_column': np.random.randn(100)
})
sns.catplot(x='x_column', y='y_column', data=data, kind='swarm')
# Out:
# c:\Users\1465151\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\1465151\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\1465151\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
'one two   three\nfour\tfive'.split()
# Out:
# ['one', 'two', 'three', 'four', 'five']

# %%
df["1st"].tolist()
# Out:
# [1, 2, 3]

# %%
df["1st"].to_list()
# Out:
# [1, 2, 3]

# %%
df.reindex(columns=["2nd", "1st"])
# Out:
#    2nd  1st
# 0   11    1
# 1   12    2
# 2   13    3

# %%
df.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.hist()
# Out:
# array([[<Axes: title={'center': '1st'}>, <Axes: title={'center': '2nd'}>]],
#       dtype=object)

# %%
plt.rcParams
# Out:
# RcParams({'_internal.classic_mode': False,
#           'agg.path.chunksize': 0,
#           'animation.bitrate': -1,
#           'animation.codec': 'h264',
#           'animation.convert_args': ['-layers', 'OptimizePlus'],
#           'animation.convert_path': 'convert',
#           'animation.embed_limit': 20.0,
#           'animation.ffmpeg_args': [],
#           'animation.ffmpeg_path': 'ffmpeg',
#           'animation.frame_format': 'png',
#           'animation.html': 'none',
#           'animation.writer': 'ffmpeg',
#           'axes.autolimit_mode': 'data',
#           'axes.axisbelow': 'line',
#           'axes.edgecolor': 'black',
#           'axes.facecolor': 'white',
#           'axes.formatter.limits': [-5, 6],
#           'axes.formatter.min_exponent': 0,
#           'axes.formatter.offset_threshold': 4,
#           'axes.formatter.use_locale': False,
#           'axes.formatter.use_mathtext': False,
#           'axes.formatter.useoffset': True,
# ...

# %%
df.index = [1, 2, 3]
print(df.index.tolist())
df.index = [0, 1, 2]
print(df.index.tolist())
# Out:
# [1, 2, 3]
# [0, 1, 2]

# %%
df.columns = ["first", "second"]
print(df.columns.tolist())
df.columns = ["1st", "2nd"]
print(df.columns.tolist())
# Out:
# ['first', 'second']
# ['1st', '2nd']

# %%
column_data = df['1st']
column_data
# Out:
# 0    1
# 1    2
# 2    3
# Name: 1st, dtype: int64
